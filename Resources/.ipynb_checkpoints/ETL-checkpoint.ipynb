# %%
# this assumes that you have already downloaded the 2013 and 2018 data
# named "all_data_2013" and "all_data 2018"
# and they are in the same folder as this notebook

# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import numpy
import statsmodels.api as sm

# %%
automation = "automation_likelihood.csv"
data_2013 = "oes_data_2013.xlsx"
data_2018 = "all_data_M_2018.xlsx"

# %%
automation_df = pd.read_csv(automation, encoding = 'unicode_escape')
automation_df.head()
# Out:
#        SOC                           Occupation  Probability  Alabama  Alaska  \
# 0  11-1011                     Chief Executives        0.015     1030     760
# 1  11-1021      General and Operations Managers        0.160    26930    6490
# 2  11-2011  Advertising and Promotions Managers        0.039       50      40
# 3  11-2021                   Marketing Managers        0.014      530     200
# 4  11-2022                       Sales Managers        0.013     2510     400
#
#    Arizona  Arkansas  California  Colorado  Connecticut  ...  South Dakota  \
# 0     5750      2710       31150       880         1410  ...           560
# 1    43300     20680      261780     41540        33280  ...          3730
# 2      470       110        3760       480          300  ...             0
# 3     4790      1090       33390      3060         4970  ...            60
# 4    10650      2650       69180      4570         7040  ...           300
#
#    Tennessee   Texas   Utah  Vermont  Virginia  Washington  West Virginia  \
# 0       5460    5890   3650      280      6320        5910            980
# 1      44400  168610  36200     2760     52380       43760          10200
# 2        670    1210    380       40       240         640             40
# 3       3400    9570   2320      380      3840        5830            260
# 4       8890   22310   3360      480      5360        7390            600
#
#    Wisconsin  Wyoming
# 0       3740      160
# 1      32350     4840
# 2        200        0
# 3       2980       30
# 4       5730      180
#
# [5 rows x 54 columns]

# %%
automation_list = list(automation_df['SOC'])
len(automation_list)
# Out:
# 702

# %%
data_2013_df = pd.read_excel(data_2013)
data_2013_df.head(5)
# Out:
#    area area_title  area_type   naics     naics_title  own_code occ_code  \
# 0    99       U.S.          1  000000  Cross-industry      1235  00-0000
# 1    99       U.S.          1  000000  Cross-industry      1235  11-0000
# 2    99       U.S.          1  000000  Cross-industry      1235  11-1000
# 3    99       U.S.          1  000000  Cross-industry      1235  11-1010
# 4    99       U.S.          1  000000  Cross-industry      1235  11-1011
#
#                 occ_title   group    tot_emp  ... h_median h_pct75 h_pct90  \
# 0         All Occupations   total  132588810  ...    16.87   27.34   42.47
# 1  Management Occupations   major    6542950  ...    45.96   66.45       #
# 2          Top Executives   minor    2278260  ...    48.22   75.55       #
# 3        Chief Executives   broad     248760  ...     82.5       #       #
# 4        Chief Executives  detail     248760  ...     82.5       #       #
#
#   a_pct10 a_pct25 a_median a_pct75 a_pct90 annual hourly
# 0   18190   22670    35080   56860   88330
# 1   46340   66660    95600  138220       #
# 2   44630   66850   100310  157150       #
# 3   75030  110610   171610       #       #
# 4   75030  110610   171610       #       #
#
# [5 rows x 29 columns]

# %%
columns_2013 = data_2013_df[['occ_code','occ_title','tot_emp','h_median','a_median']].copy()
columns_2013.head()
# Out:
#   occ_code               occ_title    tot_emp h_median a_median
# 0  00-0000         All Occupations  132588810    16.87    35080
# 1  11-0000  Management Occupations    6542950    45.96    95600
# 2  11-1000          Top Executives    2278260    48.22   100310
# 3  11-1010        Chief Executives     248760     82.5   171610
# 4  11-1011        Chief Executives     248760     82.5   171610

# %%
unique_2013 = columns_2013.drop_duplicates(subset='occ_code', keep='first')
len(unique_2013)
# Out:
# 1396

# %%
final_2013_data = unique_2013[unique_2013['occ_code'].isin(automation_list)]
len(final_2013_data)
# Out:
# 689

# %%
#final_2013_data.to_csv("../Output/final_2013_data.csv", index=False)

# %%
data_2018_df = pd.read_excel(data_2018)
data_2018_df.head(5)
# Out:
#    area area_title  area_type   naics     naics_title         i_group  \
# 0    99       U.S.          1  000000  Cross-industry  cross-industry
# 1    99       U.S.          1  000000  Cross-industry  cross-industry
# 2    99       U.S.          1  000000  Cross-industry  cross-industry
# 3    99       U.S.          1  000000  Cross-industry  cross-industry
# 4    99       U.S.          1  000000  Cross-industry  cross-industry
#
#    own_code occ_code               occ_title   o_group  ... h_median h_pct75  \
# 0      1235  00-0000         All Occupations     total  ...    18.58   30.06
# 1      1235  11-0000  Management Occupations     major  ...    50.11   72.93
# 2      1235  11-1000          Top Executives     minor  ...    49.73   78.81
# 3      1235  11-1010        Chief Executives     broad  ...    91.15       #
# 4      1235  11-1011        Chief Executives  detailed  ...    91.15       #
#
#   h_pct90 a_pct10 a_pct25 a_median a_pct75 a_pct90 annual hourly
# 0   47.31   20690   25740    38640   62510   98410    NaN    NaN
# 1       #   49260   70880   104240  151700       #    NaN    NaN
# 2       #   43400   66000   103450  163930       #    NaN    NaN
# 3       #   68360  115960   189600       #       #    NaN    NaN
# 4       #   68360  115960   189600       #       #    NaN    NaN
#
# [5 rows x 30 columns]

# %%
columns_2018 = data_2018_df[['occ_code','occ_title','tot_emp','h_median','a_median']].copy()
columns_2018.head()
# Out:
#   occ_code               occ_title    tot_emp h_median a_median
# 0  00-0000         All Occupations  144733270    18.58    38640
# 1  11-0000  Management Occupations    7616650    50.11   104240
# 2  11-1000          Top Executives    2535640    49.73   103450
# 3  11-1010        Chief Executives     195530    91.15   189600
# 4  11-1011        Chief Executives     195530    91.15   189600

# %%
unique_2018 = columns_2018.drop_duplicates(subset='occ_code', keep='first')
len(unique_2018)
# Out:
# 1373

# %%
final_2018_data = unique_2018[unique_2018['occ_code'].isin(automation_list)]
len(final_2018_data)
# Out:
# 669

# %%
final_2018_data.to_csv("final_2018_data.csv", index=False)

# %%
final_combined = pd.merge(final_2013_data, final_2018_data, left_on='occ_code', right_on='occ_code', suffixes=('_2013', '_2018'))

final_combined.loc[final_combined['h_median_2018'].isin(['*', '#'])]=0

final_combined.loc[final_combined['a_median_2018'].isin(['*', '#'])]=0
final_combined.loc[final_combined['h_median_2013'].isin(['*', '#'])]= 0
final_combined.loc[final_combined['a_median_2013'].isin(['*', '#'])]= 0
final_combined = final_combined[final_combined.loc[:]!=0].dropna()
inflation_2018 = final_combined["a_median_2018"]*0.9221
final_combined['adj_a_median_2018'] = inflation_2018
final_combined.head()
# final_combined.to_csv("final_2018_data.csv", index=False)

percentage_change_a_median = (final_combined['a_median_2013'] - final_combined['adj_a_median_2018'])/final_combined['a_median_2013']
percentage_change_tot_emp = (final_combined['tot_emp_2013'] - final_combined['tot_emp_2018'])/final_combined['tot_emp_2013']
#print(len(percentage_change_a_median))
df1 = pd.DataFrame({ "occ_code": final_combined['occ_code'],
                     "per_change_ma": percentage_change_a_median,
                     "per_change_emp": percentage_change_tot_emp})
df2 = pd.DataFrame({"occ_code": automation_df['SOC'],
                             "occ_title": automation_df['Occupation'],
                             "probability": automation_df['Probability']})
table2_combined = pd.merge(df1, df2, left_on='occ_code', right_on='occ_code')
table2_combined = table2_combined[['occ_code','occ_title','probability','per_change_ma','per_change_emp']]
table2_combined.head()
# Out:
#   occ_code                            occ_title  probability per_change_ma  \
# 0  11-1011                     Chief Executives        0.015    -0.0187644
# 1  11-1021      General and Operations Managers        0.160     0.0348693
# 2  11-2011  Advertising and Promotions Managers        0.039     -0.150464
# 3  11-2021                   Marketing Managers        0.014   -0.00494083
# 4  11-2022                       Sales Managers        0.013    -0.0553092
#
#   per_change_emp
# 0       0.213981
# 1      -0.160141
# 2       0.114616
# 3       -0.38176
# 4      -0.076174

# %%
rds_connection_string = "postgres:DarkHoney31$@localhost:5432/ETLProject"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['bls', 'automation', 'BLS']

# %%
final_combined.to_sql(name='bls', con=engine, if_exists='append', index=False)
pd.read_sql_query('select * from bls ', con=engine).head()
# Out:
#   occ_code                       occ_title_2013  tot_emp_2013  h_median_2013  \
# 0  11-1011                     Chief Executives        248760          82.50
# 1  11-1021      General and Operations Managers       1973700          46.36
# 2  11-2011  Advertising and Promotions Managers         28530          45.13
# 3  11-2021                   Marketing Managers        174010          59.24
# 4  11-2022                       Sales Managers        352220          52.18
#
#    a_median_2013                       occ_title_2018  tot_emp_2018  \
# 0       171610.0                     Chief Executives        195530
# 1        96430.0      General and Operations Managers       2289770
# 2        93880.0  Advertising and Promotions Managers         25260
# 3       123220.0                   Marketing Managers        240440
# 4       108540.0                       Sales Managers        379050
#
#    h_median_2018  a_median_2018  adj_a_median_2018
# 0          91.15       189600.0         174830.160
# 1          48.52       100930.0          93067.553
# 2          56.31       117130.0         108005.573
# 3          64.56       134290.0         123828.809
# 4          59.72       124220.0         114543.262

# %%
table2_combined.to_sql(name='automation', con=engine, if_exists='append', index=False)
pd.read_sql_query('select * from automation', con=engine).head()
# Out:
#    id occ_code                            occ_title  probability  \
# 0   1  11-1011                     Chief Executives        0.015
# 1   2  11-1021      General and Operations Managers        0.160
# 2   3  11-2011  Advertising and Promotions Managers        0.039
# 3   4  11-2021                   Marketing Managers        0.014
# 4   5  11-2022                       Sales Managers        0.013
#
#    per_change_ma  per_change_emp
# 0      -0.018764        0.213981
# 1       0.034869       -0.160141
# 2      -0.150464        0.114616
# 3      -0.004941       -0.381760
# 4      -0.055309       -0.076174

# %%
top25=table2_combined.loc[table2_combined["probability"]>0.75]
top25
# Out:
#     occ_code                                          occ_title  probability  \
# 12   11-3111                 Compensation and Benefits Managers         0.96
# 26   11-9141  Property; Real Estate; and Community Associati...         0.81
# 31   13-1031     Claims Adjusters; Examiners; and Investigators         0.98
# 32   13-1032                  Insurance Appraisers; Auto Damage         0.98
# 35   13-1074                             Farm Labor Contractors         0.97
# 43   13-2011                           Accountants and Auditors         0.94
# 44   13-2021            Appraisers and Assessors of Real Estate         0.90
# 45   13-2031                                    Budget Analysts         0.94
# 46   13-2041                                    Credit Analysts         0.98
# 49   13-2053                             Insurance Underwriters         0.99
# 52   13-2072                                      Loan Officers         0.98
# 53   13-2081   Tax Examiners and Collectors; and Revenue Agents         0.93
# 54   13-2082                                      Tax Preparers         0.99
# 70   17-1021                Cartographers and Photogrammetrists         0.88
# 91   17-3012                Electrical and Electronics Drafters         0.81
# 95   17-3023  Electrical and Electronics Engineering Technic...         0.84
# 96   17-3024                     Electro-Mechanical Technicians         0.81
# 101  17-3031                  Surveying and Mapping Technicians         0.96
# 134  19-4011          Agricultural and Food Science Technicians         0.97
# 137  19-4041               Geological and Petroleum Technicians         0.91
# 138  19-4051                                Nuclear Technicians         0.85
# 140  19-4091  Environmental Science and Protection Technicia...         0.77
# 160  23-2011                    Paralegals and Legal Assistants         0.94
# 162  23-2093        Title Examiners; Abstractors; and Searchers         0.99
# 166  25-4011                                         Archivists         0.76
# 170  25-4031                                Library Technicians         0.99
# 194  27-3042                                  Technical Writers         0.89
# 199  27-4013                                    Radio Operators         0.98
# 227  29-2052                               Pharmacy Technicians         0.92
# 233  29-2071  Medical Records and Health Information Technic...         0.91
# ..       ...                                                ...          ...
# 597  51-9194                              Etchers and Engravers         0.98
# 598  51-9195  Molders; Shapers; and Casters; Except Metal an...         0.90
# 600  51-9197                                      Tire Builders         0.94
# 607  53-3022              Bus Drivers; School or Special Client         0.89
# 608  53-3031                               Driver/Sales Workers         0.98
# 609  53-3032            Heavy and Tractor-Trailer Truck Drivers         0.79
# 611  53-3041                        Taxi Drivers and Chauffeurs         0.89
# 612  53-4011                               Locomotive Engineers         0.96
# 613  53-4012                                  Locomotive Firers         0.93
# 614  53-4013  Rail Yard Engineers; Dinkey Operators; and Hos...         0.91
# 615  53-4021       Railroad Brake; Signal; and Switch Operators         0.83
# 616  53-4031                Railroad Conductors and Yardmasters         0.83
# 617  53-4041                     Subway and Streetcar Operators         0.86
# 618  53-5011                          Sailors and Marine Oilers         0.83
# 622  53-6011                            Bridge and Lock Tenders         0.97
# 623  53-6021                             Parking Lot Attendants         0.87
# 624  53-6031       Automotive and Watercraft Service Attendants         0.83
# 625  53-6041                                Traffic Technicians         0.90
# 626  53-6051                          Transportation Inspectors         0.90
# 628  53-7011                     Conveyor Operators and Tenders         0.93
# 629  53-7021                          Crane and Tower Operators         0.90
# 630  53-7031                                   Dredge Operators         0.92
# 631  53-7032  Excavating and Loading Machine and Dragline Op...         0.94
# 634  53-7051             Industrial Truck and Tractor Operators         0.93
# 636  53-7062  Laborers and Freight; Stock; and Material Move...         0.85
# 637  53-7063                     Machine Feeders and Offbearers         0.93
# 639  53-7071   Gas Compressor and Gas Pumping Station Operators         0.91
# 640  53-7072            Pump Operators; Except Wellhead Pumpers         0.90
# 641  53-7073                                   Wellhead Pumpers         0.84
# 642  53-7081          Refuse and Recyclable Material Collectors         0.93
#
#     per_change_ma per_change_emp
# 12     -0.0994514       0.108708
# 26     -0.0111901      -0.220475
# 31     0.00692286      -0.044392
# 32      0.0650391      -0.153263
# 35      -0.201098       0.834711
# 43     0.00110556     -0.0784025
# 44     0.00652444      0.0383657
# 45    -0.00245988       0.100953
# 46      -0.029964      -0.125282
# 49    -0.00306206     -0.0378215
# 52      0.0535789     -0.0102365
# 53     0.00811847       0.158049
# 54     -0.0286468    -0.00412918
# 70    -0.00970263      0.0212578
# 91      0.0324795       0.158784
# 95     -0.0133019       0.100602
# 96     -0.0381484       0.129987
# 101   -0.00621583     -0.0907195
# 134    -0.0829838     -0.0979887
# 137     0.0797991     0.00855826
# 138   -0.00502677       -0.04329
# 140    -0.0209438      0.0553463
# 160     0.0125757      -0.142341
# 162     -0.014676      0.0272185
# 166     0.0191304      -0.145683
# 170   -0.00346176      0.0759533
# 194      0.024258      -0.064482
# 199      0.127497           0.25
# 227    -0.0169535      -0.152113
# 233    -0.0639615      -0.154293
# ..            ...            ...
# 597    -0.0133074    -0.00350058
# 598    -0.0319844      -0.291009
# 600    -0.0827883      -0.361411
# 607    -0.0552235     -0.0162061
# 608   -0.00245907     -0.0463843
# 609    -0.0407578       -0.13564
# 611    -0.0488686      -0.222843
# 612    -0.0741401      0.0545307
# 613     -0.310363       0.702128
# 614     -0.147827      -0.107004
# 615    -0.0385414       0.404175
# 616    -0.0351008      0.0171694
# 617     0.0125737     0.00895857
# 618     0.0319843      -0.118362
# 622  -0.000864366              0
# 623     -0.128745       -0.12067
# 624    -0.0901231    -0.00699301
# 625     -0.078137      -0.172026
# 626    -0.0315775      -0.251147
# 628    0.00553113       0.426153
# 629    -0.0265781     -0.0680616
# 630    -0.0541613           0.32
# 631    -0.0493925     -0.0292541
# 634    -0.0427262       -0.19734
# 636    -0.0871317      -0.266356
# 637     0.0371856       0.374717
# 639     -0.104927       0.234513
# 640     0.0542455       0.178436
# 641    -0.0731751     0.00969426
# 642    -0.0500442     -0.0176885
#
# [275 rows x 5 columns]

# %%
bottom25=table2_combined.loc[table2_combined["probability"]<0.25]
bottom25
# Out:
#     occ_code                                          occ_title  probability  \
# 0    11-1011                                   Chief Executives       0.0150
# 1    11-1021                    General and Operations Managers       0.1600
# 2    11-2011                Advertising and Promotions Managers       0.0390
# 3    11-2021                                 Marketing Managers       0.0140
# 4    11-2022                                     Sales Managers       0.0130
# 5    11-2031          Public Relations and Fundraising Managers       0.0150
# 7    11-3021          Computer and Information Systems Managers       0.0350
# 8    11-3031                                 Financial Managers       0.0690
# 9    11-3051                     Industrial Production Managers       0.0300
# 10   11-3061                                Purchasing Managers       0.0300
# 13   11-3121                           Human Resources Managers       0.0055
# 14   11-3131                  Training and Development Managers       0.0063
# 15   11-9013  Farmers; Ranchers; and Other Agricultural Mana...       0.0470
# 16   11-9021                              Construction Managers       0.0710
# 17   11-9031  Education Administrators; Preschool and Childc...       0.0150
# 18   11-9033            Education Administrators; Postsecondary       0.0100
# 19   11-9041             Architectural and Engineering Managers       0.0170
# 20   11-9051                              Food Service Managers       0.0830
# 21   11-9071                                    Gaming Managers       0.0910
# 22   11-9081                                   Lodging Managers       0.0039
# 23   11-9111               Medical and Health Services Managers       0.0073
# 24   11-9121                          Natural Sciences Managers       0.0180
# 27   11-9151              Social and Community Service Managers       0.0067
# 28   11-9161                     Emergency Management Directors       0.0030
# 30   13-1011  Agents and Business Managers of Artists; Perfo...       0.2400
# 33   13-1041                                Compliance Officers       0.0800
# 36   13-1081                                       Logisticians       0.0120
# 37   13-1111                                Management Analysts       0.1300
# 38   13-1121            Meeting; Convention; and Event Planners       0.0370
# 40   13-1151               Training and Development Specialists       0.0140
# ..       ...                                                ...          ...
# 260  33-3031                              Fish and Game Wardens       0.0800
# 262  33-3051               Police and Sheriffs Patrol Officers       0.0980
# 264  33-9011                             Animal Control Workers       0.2100
# 270  35-1011                               Chefs and Head Cooks       0.1000
# 294  39-1021  First-Line Supervisors of Personal Service Wor...       0.0760
# 295  39-2011                                    Animal Trainers       0.1000
# 307  39-5012     Hairdressers; Hairstylists; and Cosmetologists       0.1100
# 308  39-5091         Makeup Artists; Theatrical and Performance       0.0100
# 313  39-6012                                         Concierges       0.2100
# 314  39-9011                                  Childcare Workers       0.0840
# 316  39-9031          Fitness Trainers and Aerobics Instructors       0.0850
# 317  39-9032                                 Recreation Workers       0.0061
# 318  39-9041                               Residential Advisors       0.0640
# 320  41-1012  First-Line Supervisors of Non-Retail Sales Wor...       0.0750
# 328  41-3031  Securities; Commodities; and Financial Service...       0.0160
# 329  41-3041                                      Travel Agents       0.0990
# 336  41-9031                                    Sales Engineers       0.0041
# 339  43-1011  First-Line Supervisors of Office and Administr...       0.0140
# 384  43-9031                                 Desktop Publishers       0.1600
# 400  47-1011  First-Line Supervisors of Construction Trades ...       0.1700
# 417  47-2111                                       Electricians       0.1500
# 454  49-1011  First-Line Supervisors of Mechanics; Installer...       0.0030
# 488  49-9051     Electrical Power-Line Installers and Repairers       0.0970
# 496  49-9092                                  Commercial Divers       0.1800
# 499  49-9095   Manufactured Building and Mobile Home Installers       0.1800
# 503  51-1011  First-Line Supervisors of Production and Opera...       0.0160
# 557  51-6092                   Fabric and Apparel Patternmakers       0.0049
# 602  53-1011                Aircraft Cargo Handling Supervisors       0.0660
# 603  53-2021                            Air Traffic Controllers       0.1100
# 621  53-5031                                     Ship Engineers       0.0410
#
#     per_change_ma per_change_emp
# 0      -0.0187644       0.213981
# 1       0.0348693      -0.160141
# 2       -0.150464       0.114616
# 3     -0.00494083       -0.38176
# 4      -0.0553092      -0.076174
# 5      -0.0725135      -0.348595
# 7       -0.060322      -0.226746
# 8      -0.0472012      -0.217896
# 9      -0.0499691     -0.0965888
# 10     -0.0567987     0.00186728
# 13     -0.0364477      -0.297605
# 14     -0.0390306      -0.259351
# 15       0.106309      -0.265252
# 16     -0.0199796       -0.30292
# 17       0.015249     -0.0649706
# 18     0.00479449       -0.13527
# 19     -0.0126769     -0.0264951
# 20     -0.0402393      -0.147254
# 21     -0.0404965      0.0358744
# 22     -0.0512688      -0.197092
# 23     -0.0112275      -0.241488
# 24      0.0224982      -0.161079
# 27      0.0151803      -0.299488
# 28      -0.093066      0.0255102
# 30      0.0557376      -0.269692
# 33      0.0131208      -0.274514
# 36      0.0628248      -0.411168
# 37      0.0347217      -0.205392
# 38      0.0159084      -0.502524
# 40      0.0126961      -0.300165
# ..            ...            ...
# 260    -0.0913534      0.0903614
# 262   -0.00834666     -0.0408417
# 264    -0.0462178       0.111111
# 270    -0.0516584      -0.193725
# 294   -0.00307762      -0.521091
# 295    -0.0666789      -0.397738
# 307     0.0145405     -0.0717411
# 308     -0.254923      -0.286885
# 313   -0.00797699      -0.241802
# 314    -0.0933471      0.0556448
# 316     -0.111993      -0.295167
# 317    -0.0320601      -0.114273
# 318    -0.0477042       -0.22852
# 320     0.0409167    -0.00728294
# 328      0.186054      -0.279111
# 329     -0.033457     -0.0814008
# 336    0.00405344    0.000152138
# 339    -0.0253517     -0.0812654
# 384    -0.0453715       0.252089
# 400    0.00383268      -0.280607
# 417    -0.0075371      -0.208521
# 454    0.00379461      -0.100789
# 488    -0.0189514     -0.0309834
# 496     0.0546214      0.0611111
# 499    -0.0208737       0.168091
# 503    -0.0187106     -0.0726293
# 557     0.0680195       0.138614
# 602   0.000372859      -0.422648
# 603      0.053114      0.0290546
# 621     0.0584414       0.119839
#
# [193 rows x 5 columns]

# %%
Automation_desc=table2_combined.sort_values(by='probability',ascending=False).head(20)
Automation_desc
# Out:
#     occ_code                                          occ_title  probability  \
# 162  23-2093        Title Examiners; Abstractors; and Searchers         0.99
# 49   13-2053                             Insurance Underwriters         0.99
# 493  49-9064                                    Watch Repairers         0.99
# 360  43-4141                                New Accounts Clerks         0.99
# 382  43-9021                                  Data Entry Keyers         0.99
# 550  51-6051                                       Sewers; Hand         0.99
# 170  25-4031                                Library Technicians         0.99
# 593  51-9151  Photographic Process Workers and Processing Ma...         0.99
# 365  43-5011                           Cargo and Freight Agents         0.99
# 337  41-9041                                      Telemarketers         0.99
# 54   13-2082                                      Tax Preparers         0.99
# 52   13-2072                                      Loan Officers         0.98
# 46   13-2041                                    Credit Analysts         0.98
# 324  41-2022                                 Parts Salespersons         0.98
# 385  43-9041      Insurance Claims and Policy Processing Clerks         0.98
# 597  51-9194                              Etchers and Engravers         0.98
# 333  41-9012                                             Models         0.98
# 378  43-6012                                  Legal Secretaries         0.98
# 608  53-3031                               Driver/Sales Workers         0.98
# 588  51-9111  Packaging and Filling Machine Operators and Te...         0.98
#
#     per_change_ma per_change_emp
# 162     -0.014676      0.0272185
# 49    -0.00306206     -0.0378215
# 493    -0.0378176      0.0809859
# 360    0.00538777       0.271802
# 382    -0.0419374       0.157613
# 550      -0.11894      0.0614035
# 170   -0.00346176      0.0759533
# 593     -0.128644       0.550768
# 365     0.0100884      -0.251085
# 337    -0.0297667       0.292109
# 54     -0.0286468    -0.00412918
# 52      0.0535789     -0.0102365
# 46      -0.029964      -0.125282
# 324     0.0468919      -0.151851
# 385    -0.0093979      -0.162602
# 597    -0.0133074    -0.00350058
# 333     -0.151172       0.394881
# 378    -0.0084585       0.198477
# 608   -0.00245907     -0.0463843
# 588    -0.0570329     -0.0621155

# %%
Automation_desc.plot.bar(x='occ_title',y='per_change_emp',rot=90)

# %%
Automation_desc.plot.bar(x='occ_title',y='per_change_ma',rot=90)

# %%
Automation_asc=table2_combined.sort_values(by='probability',ascending=True).head(10)
Automation_asc
# Out:
#     occ_code                                          occ_title  probability  \
# 215  29-1125                            Recreational Therapists       0.0028
# 28   11-9161                     Emergency Management Directors       0.0030
# 454  49-1011  First-Line Supervisors of Mechanics; Installer...       0.0030
# 149  21-1023   Mental Health and Substance Abuse Social Workers       0.0031
# 219  29-1181                                       Audiologists       0.0033
# 148  21-1022                          Healthcare Social Workers       0.0035
# 235  29-2091                        Orthotists and Prosthetists       0.0035
# 212  29-1122                            Occupational Therapists       0.0035
# 253  33-1021  First-Line Supervisors of Fire Fighting and Pr...       0.0036
# 22   11-9081                                   Lodging Managers       0.0039
#
#     per_change_ma per_change_emp
# 215    -0.0220404     -0.0107296
# 28      -0.093066      0.0255102
# 454    0.00379461      -0.100789
# 149   -0.00920098     -0.0612672
# 219     0.0163576      -0.151515
# 148     -0.019717      -0.185856
# 235    -0.0121574      -0.060024
# 212   -0.00994758      -0.170556
# 253   -0.00490995      -0.104188
# 22     -0.0512688      -0.197092

# %%
Automation_asc.plot.bar(x='occ_title',y='per_change_emp',rot=90)

# %%
Automation_asc.plot.bar(x='occ_title',y='per_change_ma',rot=90)

# %%
prob = list(top25['probability'])
ma = list(top25['per_change_ma'])
emp = list(top25['per_change_emp'])

# %%
X = prob
y = ma
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     5.749
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):             0.0269
# Time:                        19:04:23   Log-Likelihood:                 31.050
# No. Observations:                  20   AIC:                            -60.10
# Df Residuals:                      19   BIC:                            -59.10
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0286      0.012     -2.398      0.027      -0.054      -0.004
# ==============================================================================
# Omnibus:                        5.109   Durbin-Watson:                   2.408
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                3.150
# Skew:                          -0.941   Prob(JB):                        0.207
# Kurtosis:                       3.490   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = prob
z = emp
model = sm.OLS(z, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     2.001
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):              0.173
# Time:                        19:04:31   Log-Likelihood:                 4.3786
# No. Observations:                  20   AIC:                            -6.757
# Df Residuals:                      19   BIC:                            -5.761
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0640      0.045      1.414      0.173      -0.031       0.159
# ==============================================================================
# Omnibus:                        3.303   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.192   Jarque-Bera (JB):                1.993
# Skew:                           0.769   Prob(JB):                        0.369
# Kurtosis:                       3.153   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
prob1 = list(bottom25['probability'])
ma1 = list(bottom25['per_change_ma'])
emp1 = list(bottom25['per_change_emp'])

# %%
X1= prob1
y1 = ma1
model1 = sm.OLS(y1, X1).fit()
model1.summary()
# Out:
# C:\Users\tharu\Anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     4.107
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):             0.0733
# Time:                        18:55:14   Log-Likelihood:                 20.994
# No. Observations:                  10   AIC:                            -39.99
# Df Residuals:                       9   BIC:                            -39.69
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -6.0046      2.963     -2.027      0.073     -12.707       0.698
# ==============================================================================
# Omnibus:                        9.775   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                4.205
# Skew:                          -1.427   Prob(JB):                        0.122
# Kurtosis:                       4.395   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X1= prob1
z1= emp1
model1 = sm.OLS(z1, X1).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     24.83
# Date:                Thu, 08 Aug 2019   Prob (F-statistic):           1.39e-06
# Time:                        19:05:42   Log-Likelihood:                 30.842
# No. Observations:                 193   AIC:                            -59.68
# Df Residuals:                     192   BIC:                            -56.42
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.8527      0.171     -4.983      0.000      -1.190      -0.515
# ==============================================================================
# Omnibus:                        7.792   Durbin-Watson:                   1.536
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):               13.311
# Skew:                          -0.121   Prob(JB):                      0.00129
# Kurtosis:                       4.264   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
